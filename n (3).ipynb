# %%
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
website_url = requests.get(url).text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(website_url,'lxml')

# %%
my_table = soup.find('table',{'class':'wikitable sortable'})

# %%
links = my_table.findAll('td')
# str(links[5])[4:-6]
links[0]
# Out:
# <td>M1A
# </td>

# %%
f'number of rows in our table is: {len(links)/3}'
# Out:
# 'number of rows in our table is: 180.0'

# %%
Postcodes = [] 
Boroughs = [] 
neighborhoods = []

i = 0

for word in links:
  if i%3 == 0:
    Postcodes.append(word.get_text().strip())
    
  elif i%3 == 1:
    Boroughs.append(word.get_text().strip())
  
  elif i%3 == 2:
    neighborhoods.append(word.get_text().strip())
  i+=1

# %%
len(neighborhoods) == len(Boroughs) == len(Postcodes)
# Out:
# True

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df['Postalcodes'] = Postcodes
df['Borough'] = Boroughs
df['neighborhood'] = neighborhoods
df[df['Postalcodes']== 'M1R']
# Out:
#     Postalcodes      Borough       neighborhood
# 108         M1R  Scarborough  Wexford, Maryvale

# %%
indexes = []
for index, row in df.iterrows():
  if row['Borough'] == 'Not assigned':
    indexes.append(index)
    continue
  elif row['neighborhood'] == 'Not assigned':
    row['neighborhood'] == row['Borough']
df.head()
# Out:
#   Postalcodes           Borough               neighborhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df.drop(indexes, inplace=True)
df.head()
# Out:
#   Postalcodes           Borough                                 neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df1 = df.groupby('Postalcodes')['neighborhood'].apply(', '.join).reset_index()
df1.head()
# Out:
#   Postalcodes                            neighborhood
# 0         M1B                          Malvern, Rouge
# 1         M1C  Rouge Hill, Port Union, Highland Creek
# 2         M1E       Guildwood, Morningside, West Hill
# 3         M1G                                  Woburn
# 4         M1H                               Cedarbrae

# %%
df = pd.merge( df[['Postalcodes','Borough']], df1[['Postalcodes','neighborhood']], on='Postalcodes')
df.head()
# Out:
#   Postalcodes           Borough                                 neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)

# %%
# !wget -O geospatial_data.csv 'http://cocl.us/Geospatial_data'
# Out:
# --2020-12-12 06:41:00--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.63.96.194, 169.63.96.176
# Connecting to cocl.us (cocl.us)|169.63.96.194|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2020-12-12 06:41:01--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.63.96.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-12-12 06:41:02--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.29.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.29.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-12-12 06:41:02--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-12-12 06:41:02--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.29.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.29.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!uiAiFFsA9Sdd1HIk0Lq7dCe8nB5Umg0ebw6DEO52H18l2x4u8yjBIPe2M2we2L0iqot-BszlpiPbcKbhb5L-lC3UYBEhOas76HL3TuTZjqkUOmjmg95bqmgeL97XN4MDIOuGfu5a3DVytaxEcUt4IyQJYuDzZlRW99cynrf-C3xAlPfTUHC_aqBE8h0WTnmqWTtEsbj1KVEGDAkivfkx9lnz4ZacAC7P9zUeuuX1p8kZYGiGXtZkHt_OsHse4AlJ3vK6Z0
XtZkHt_OsHse4AlJ3vK6Z0OQJuOLUAS2WMb7LxqUzS-3hd-KSYn3rFl9TCv-t734EDeTBxQC8r6HBhqcbuvu-7kgzQLEJtBV-pWkka83R72WYFRgh3QAzRqQ9RQI5NPWimggjzT10Q5Ww5osQ_4QMsczCw9yH87wiLwL9SO_pfKL3zkfZqph4A955ZJLBngGYID_H-2EIjESiXsVsOE-F0w656GaMSCI61pDRPkJW4i8jD1aygfqKdH0xuFr90VOS8YfbN1FvHpD1mH6Q_Z5TaOmfpFbRxYeM2yqUK47vtglf5crRh_qaECYnaiMyWAleLXXnSAloX1-zeSHHk_JSzuhqUEp-Zy2fW9cqd_kARTw1nWv8b0woweowKNtQO8DYcL5PxpeSwsf1AgmrhAtwqKtrN_dMfHCy6v0KTAcnadv9On0N1Z3F4B_MyTI6RRZHKlN53WJLW0bvmDsyyHq8rJXeu-nm6-GjW09ORN2fgGINtlQqGZO2eakVlJehKLbpUX2KCh2sXhKZo3DpINYIkClOlwqMzzWk0qEwwDV-3dmRjIiqB08fItVklSndu2BFyLGF98LR8a4b4ZGGLtfPobKF2Gd0H_eUaKpvMm8jH8nT0LcvS-EXFYil-3HzM8wwDm6DZ9CpwW8Iuamwo3TFyKCb1LxFgBOuMiZMEXMSAz9n6Bysi9wG3jQLa-3iUIXUsehlYgbQG22GCS_i6VU-YMTolFG3KZvwhbLZTvi7bAFatbkcDpdamC3Puz54Y50ZUrvSg6npq_B_H_q9FBjoTC1HK3peLLo9NoMuz-en-oy3kj5IH5yB4Sm9ComXnwV2Ad8vZ6t_MRbi9OLQj53oC9vzDuJctD9URpAYqz325oSy4MDh42kWCex-cszotgDa4dXJ6lVZYJvXvsGgoGSIBKVJ5k79NzWAmJz9qAAsI4M56Eg2j0GYloNJ70mtxzLEsvcmo-YNlesuSLUDVL2amb97W26a6MohYmTZjLP7G-T7GNUFFia4R0fwYWmUM0xkyLAnbSKOBKQhlt48SYB1dGnVXx77SjsWk93UNWBzlIW9piUrag2qimSf9oSEhZgxhTm5sw7y_OGj7EC6i5Na8blJD81PJVNgONBqNJtg6QVveK3Fn3fUrTln92PVBf7hgsf-xUDHhT3bVpNZVA-Ao08iDGqV8P_XU2GFbL8bAIXinhIqGrWEMtYQOU./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.29.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.29.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘geospatial_data.csv’
#
# geospatial_data.csv 100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2020-12-12 06:41:03 (36.8 MB/s) - ‘geospatial_data.csv’ saved [2891/2891]

# %%
geospatial_data = pd.read_csv('geospatial_data.csv')
geospatial_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geospatial_data = geospatial_data.rename(columns={"Postal Code": "Postalcodes"}, errors="raise")
geospatial_data.head()
# Out:
#   Postalcodes   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df = df.merge(geospatial_data, on='Postalcodes')
                                                        
df.head()
# Out:
#   Postalcodes           Borough                                 neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df['Borough'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.
