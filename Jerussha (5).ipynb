# %% [markdown]
# **Introduction**

# %% [markdown]
# This study is to help people choose the ideal location in Toronto to open a business by providing data about the income, population of each neighborhood and the competitors in the same regions.

# %% [markdown]
# **Data**

# %% [markdown]
# I'll be combining Toronto's Demographics on https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods which includes Population, Average income per Neighborhood with Foursquare API to collect competitors in the same neighborhoods.
