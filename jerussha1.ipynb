# %%
## This notebook will be mainly used for t
# Out:
#   File "<ipython-input-9-2657cec401ba>", line 1
#     print "This notebook will be mainly used for the capston project"
#                                                                     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("This notebook will be mainly used for the capston project")?
